# %%
import pandas as pd
import opencv as cv2
import os

# %%
df = pd.read_excel('helse_ordliste.xlsx')
video_folder = "HealthVideos"
metadata = "helse_ordliste_mod.xlsx"
aug_folder = "AugHealthVideos"
aug_resized_224 = "ResizedVideos_224"

# %%
df.head()
# Out:
#           helse_ordliste                    Unnamed: 1
# 0                    ord                         video
# 1    1. gradsforbrenning   foerstegradsforbrenning.mp4
# 2    2. gradsforbrenning     andregradsforbrenning.mp4
# 3  3. gradsforbrenning 1  tredjegradsforbrenning-1.mp4
# 4  3. gradsforbrenning 2  tredjegradsforbrenning-2.mp4

# %%
df.isnull().values.any()
# Out:
# False

# %%
#Gather video stats 
def get_video_stats(video_path):
    video_capture = cv2.VideoCapture(video_path)
    fps = video_capture.get(cv2.CAP_PROP_FPS)
    frame_count = video_capture.get(cv2.CAP_PROP_FRAME_COUNT)
    
    if fps > 0 and frame_count > 0:
        duration = frame_count / fps  
    else:
        duration = None
    
    # Get the frame size 
    frame_width = int(video_capture.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(video_capture.get(cv2.CAP_PROP_FRAME_HEIGHT))
    frame_size = (frame_width, frame_height)
    
    file_size_mb = os.path.getsize(video_path) / (1024 * 1024) 

    video_capture.release()

    return duration, frame_size, file_size_mb

# %%
# Define a function to update min/max stats
def update_min_max_stats(stats, min_stats, max_stats, video_file):
    duration, frame_size, file_size_mb = stats

    # Update min/max values for video duration
    if duration is not None:
        if duration < min_stats['min_duration']:
            min_stats['min_duration'] = duration
            min_stats['min_video'] = video_file
        if duration > max_stats['max_duration']:
            max_stats['max_duration'] = duration
            max_stats['max_video'] = video_file

    # Update min/max values for frame size
    if frame_size[0] * frame_size[1] < min_stats['min_frame_size'][0] * min_stats['min_frame_size'][1]:
        min_stats['min_frame_size'] = frame_size
        min_stats['min_frame_video'] = video_file
    if frame_size[0] * frame_size[1] > max_stats['max_frame_size'][0] * max_stats['max_frame_size'][1]:
        max_stats['max_frame_size'] = frame_size
        max_stats['max_frame_video'] = video_file

    # Update min/max values for file size
    if file_size_mb < min_stats['min_size_mb']:
        min_stats['min_size_mb'] = file_size_mb
        min_stats['min_size_video'] = video_file
    if file_size_mb > max_stats['max_size_mb']:
        max_stats['max_size_mb'] = file_size_mb
        max_stats['max_size_video'] = video_file

# %%
#Process the DF and gather stats
def process_video_files(df, video_folder):
    min_stats = {
        'min_duration': float('inf'),
        'min_video': '',
        'min_frame_size': (float('inf'), float('inf')),
        'min_frame_video': '',
        'min_size_mb': float('inf'),
        'min_size_video': ''
    }
    max_stats = {
        'max_duration': 0,
        'max_video': '',
        'max_frame_size': (0, 0),
        'max_frame_video': '',
        'max_size_mb': 0,
        'max_size_video': ''
    }

    duplicate_videos = set() 

    for index, row in df.iterrows():
        video_file = row['Video_File']

        if video_file in duplicate_videos:
            continue
        duplicate_videos.add(video_file)

        video_path = os.path.join(video_folder, video_file)

        if os.path.exists(video_path):
            stats = get_video_stats(video_path)

            update_min_max_stats(stats, min_stats, max_stats, video_file)

        else:
            print(f'File not found: {video_file}')

    return min_stats, max_stats, duplicate_videos

# %%
#Check for duplicate videos
def check_duplicates(df):
    duplicate_videos_df = df[df.duplicated(subset='Video_File', keep=False)]
    if not duplicate_videos_df.empty:
        print(f'Number of duplicates: {duplicate_videos_df.shape[0] // 2}\n')
        print('Duplicate videos and their associated terms:')
        for video, group in duplicate_videos_df.groupby('Video_File'):
            terms = group['Health_Term'].tolist()
            print(f'Video: {video} -> Terms: {", ".join(terms)}')

# %%
#Count unique terms and videos
unique_terms_count = df['Health_Term'].nunique()
print(f'Number of unique health terms: {unique_terms_count}')
num_videos = df['Video_File'].nunique()
print(f'Total number of unique videos: {num_videos}')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Emma\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Health_Term'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 2
#       1 #Count unique terms and videos
# ----> 2 unique_terms_count = df['Health_Term'].nunique()
#       3 print(f'Number of unique health terms: {unique_terms_count}')
#       4 num_videos = df['Video_File'].nunique()
#
# File c:\Users\Emma\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\Emma\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Health_Term'

# %%
def calculate_total_video_size(video_folder, df):
    total_size_mb = 0
    for _, row in df.iterrows():
        video_file = row['Video_File']
        video_path = os.path.join(video_folder, video_file)

        if os.path.exists(video_path):
            total_size_mb += os.path.getsize(video_path) / (1024 * 1024) 
        else:
            print(f'File not found: {video_file}')

    return total_size_mb

# %%
# Process the video files and get stats
min_stats, max_stats, duplicate_videos = process_video_files(df, video_folder)

print(f'Shortest video: {min_stats["min_video"]} with length {min_stats["min_duration"]:.2f} seconds')
print(f'Longest video: {max_stats["max_video"]} with length {max_stats["max_duration"]:.2f} seconds\n')

print(f'Smallest frame size: {min_stats["min_frame_video"]} with resolution {min_stats["min_frame_size"][0]}x{min_stats["min_frame_size"][1]}')
print(f'Largest frame size: {max_stats["max_frame_video"]} with resolution {max_stats["max_frame_size"][0]}x{max_stats["max_frame_size"][1]}\n')

print(f'Smallest file size: {min_stats["min_size_video"]} with size {min_stats["min_size_mb"]:.2f} MB')
print(f'Largest file size: {max_stats["max_size_video"]} with size {max_stats["max_size_mb"]:.2f} MB\n')

total_size_mb = calculate_total_video_size(video_folder, df)
print(f'Total size of all videos: {total_size_mb:.2f} MB\n')

check_duplicates(df)
# Out:
# Shortest video: fall-i-haaret.mp4 with length 0.40 seconds
# Longest video: posttraumatisk-stressforstyrrelse.mp4 with length 4.68 seconds
#
# Smallest frame size: abort.mp4 with resolution 640x480
# Largest frame size: foerstegradsforbrenning.mp4 with resolution 960x720
#
# Smallest file size: fall-i-haaret.mp4 with size 0.08 MB
# Largest file size: posttraumatisk-stressforstyrrelse.mp4 with size 0.77 MB
#
# Total size of all videos: 234.59 MB
#
# Number of duplicates: 12
#
# Duplicate videos and their associated terms:
# Video: fall-i-haaret.mp4 -> Terms: fall i håret, hår med fall
# Video: frysninger.mp4 -> Terms: frysninger, gåsehud
# Video: haar-tykt-og-kroellet.mp4 -> Terms: hår: tykt og krøllet, krøller: tykt og krøllet hår
# Video: haar-tykt-og-smaakroellet.mp4 -> Terms: hår: tykt og småkrøllet, krøller: tykt og småkrøllet hår
# Video: halvlangt-haar.mp4 -> Terms: halvlangt hår, hår: halvlangt
# Video: kirurgi.mp4 -> Terms: kirurg, kirurgi
# Video: krum-nese-oernenese.mp4 -> Terms: krum nese, ørnenese, nese: krum nese
# Video: runde-oeyne.mp4 -> Terms: øyne: runde øyne, runde øyne
# Video: sette-insulin.mp4 -> Terms: insulin (sette i-), sette insulin
# Video: smale-oeyne.mp4 -> Terms: øyne: smale øyne, smale øyne
# Video: store-runde-oeyne.mp4 -> Terms: øyne: store, runde øyne, store, runde øyne
# Video: vrikke-over-1.mp4 -> Terms: ankelforstuing, vrikke ankel 1

# %%
# Function to get the number of frames in a video
def get_video_frame_count(video_path):
    cap = cv2.VideoCapture(video_path)
    
    if not cap.isOpened():
        print(f"Could not open video {video_path}")
        return 0
    
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    
    cap.release()
    return frame_count

frame_counts = []
for video_file in os.listdir(video_folder):
    video_path = os.path.join(video_folder, video_file)
    
    if video_file.endswith('.mp4'):
        num_frames = get_video_frame_count(video_path)
        frame_counts.append((video_file, num_frames))

for video_file, num_frames in frame_counts:
    print(f'{video_file}: {num_frames} frames')
# Out:
# -fobi.mp4: 40 frames
# aande-puste.mp4: 48 frames
# aapne-munn-1.mp4: 42 frames
# aapne-munn-2.mp4: 39 frames
# aapne-oeynene-1.mp4: 41 frames
# aapne-oeynene-2.mp4: 40 frames
# aare-blodaare.mp4: 51 frames
# abort.mp4: 38 frames
# abstinens.mp4: 57 frames
# adferd-atferd.mp4: 34 frames
# aggresjon-1.mp4: 40 frames
# aggresjon-2.mp4: 44 frames
# akupunktur.mp4: 76 frames
# akutt-2.mp4: 54 frames
# akutt.mp4: 39 frames
# aldershjem.mp4: 62 frames
# alkohol.mp4: 48 frames
# alkoholfri.mp4: 56 frames
# allergi.mp4: 58 frames
# ambulanse-2.mp4: 64 frames
# ambulanse-3.mp4: 68 frames
# ambulanse.mp4: 52 frames
# amen.mp4: 52 frames
# amputere.mp4: 47 frames
# anatomi.mp4: 64 frames
# andregradsforbrenning.mp4: 81 frames
# anestesisykepleier.mp4: 81 frames
# anfall.mp4: 38 frames
# angst-2.mp4: 74 frames
# angst.mp4: 42 frames
# angstanfall.mp4: 69 frames
# angstrengelsesastma.mp4: 81 frames
# anoreksi.mp4: 61 frames
# ansikt.mp4: 35 frames
# antibiotika.mp4: 63 frames
# antidepressiva.mp4: 65 frames
# antistoff.mp4: 64 frames
# apotek.mp4: 43 frames
# appetitt.mp4: 40 frames
# arr.mp4: 52 frames
# arv.mp4: 49 frames
# arvelig.mp4: 47 frames
# astma.mp4: 56 frames
# astmaanfall.mp4: 75 frames
# attfoering.mp4: 48 frames
# audiograf.mp4: 57 frames
# audiogram.mp4: 42 frames
# audiologi.mp4: 69 frames
# autisme.mp4: 57 frames
# avfoering.mp4: 71 frames
# avhengig-personlighetsforstyrrelse.mp4: 77 frames
# avhengig.mp4: 43 frames
# bakterie.mp4: 62 frames
# balanse-1.mp4: 55 frames
# balanse-2.mp4: 51 frames
# balsamere.mp4: 76 frames
# bandasje.mp4: 58 frames
# barbere.mp4: 51 frames
# bedoevelse-tannlege.mp4: 81 frames
# bedovelse-sproyte-3.mp4: 50 frames
# bedovelse-sproyte.mp4: 53 frames
# begjaer.mp4: 63 frames
# behandle-ing.mp4: 47 frames
# behandlingsapparat.mp4: 63 frames
# bein-2.mp4: 46 frames
# bein-3.mp4: 55 frames
# beinbrudd.mp4: 59 frames
# beinbygning.mp4: 61 frames
# bekken-vannlatingskar.mp4: 52 frames
# bekymring.mp4: 51 frames
# beruset-1.mp4: 53 frames
# beruset-2.mp4: 52 frames
# besvime-lse.mp4: 40 frames
# betennelse-2.mp4: 63 frames
# betennelse.mp4: 49 frames
# bevegelseshemmet.mp4: 76 frames
# bevisst-het.mp4: 48 frames
# bevisstloes.mp4: 55 frames
# bevisstlos-2.mp4: 70 frames
# bifil-bifili.mp4: 52 frames
# bigami.mp4: 62 frames
# bihulebetennelse.mp4: 82 frames
# bindevev.mp4: 69 frames
# biologi.mp4: 46 frames
# bipolar-depresjon.mp4: 79 frames
# bite-hoggorm-bitt.mp4: 56 frames
# blaere-1.mp4: 49 frames
# blaere-2.mp4: 50 frames
# bleie.mp4: 40 frames
# blikk-syn.mp4: 53 frames
# blind-1.mp4: 46 frames
# blind-2.mp4: 40 frames
# blindtarm.mp4: 61 frames
# blinke.mp4: 60 frames
# blod-1.mp4: 54 frames
# blod-2.mp4: 51 frames
# blod-3.mp4: 54 frames
# blodaare-2.mp4: 61 frames
# blodaare.mp4: 58 frames
# blodkreft.mp4: 63 frames
# blodlegeme.mp4: 65 frames
# blodmangel.mp4: 67 frames
# blodproeve.mp4: 64 frames
# blodprove-2.mp4: 53 frames
# blodsukker.mp4: 60 frames
# blodsukkermaaler.mp4: 81 frames
# blodtrykk-2.mp4: 60 frames
# blodtrykk.mp4: 61 frames
# blodtype.mp4: 54 frames
# bloe-1.mp4: 60 frames
# bloe-2.mp4: 44 frames
# blunke.mp4: 58 frames
# boerste-tannboerste.mp4: 62 frames
# bore.mp4: 51 frames
# brennkopper-2.mp4: 65 frames
# brennkopper.mp4: 52 frames
# brille.mp4: 31 frames
# bronkitt.mp4: 68 frames
# brudd.mp4: 43 frames
# brusk.mp4: 56 frames
# bryst-kvinnebryst-1.mp4: 40 frames
# bryst-kvinnebryst-2.mp4: 53 frames
# brystkreft.mp4: 66 frames
# buk.mp4: 60 frames
# bukspyttkjertel-2.mp4: 85 frames
# bulimi.mp4: 51 frames
# celle-organisk.mp4: 64 frames
# cellegift.mp4: 55 frames
# dagkirurgi.mp4: 58 frames
# depresjon.mp4: 64 frames
# depressiv-episode.mp4: 77 frames
# diabetes-1.mp4: 69 frames
# diabetes-2.mp4: 51 frames
# diagnose-1.mp4: 62 frames
# diagnose-2.mp4: 57 frames
# diagnose.mp4: 48 frames
# diare-3.mp4: 52 frames
# diare.mp4: 62 frames
# die-patte.mp4: 55 frames
# difteri-1.mp4: 57 frames
# difteri-2.mp4: 61 frames
# disposisjon-psykisk-lidelse.mp4: 49 frames
# dissosial-personlighetsforstyrrelse.mp4: 112 frames
# doedsfall.mp4: 51 frames
# doev-2.mp4: 40 frames
# doevblind-1.mp4: 52 frames
# doevblind-2.mp4: 58 frames
# doevblitt.mp4: 58 frames
# doevhet.mp4: 54 frames
# doktor.mp4: 59 frames
# down-syndrom.mp4: 70 frames
# drypp-tia.mp4: 42 frames
# dunk-dunk-hjerteslag.mp4: 56 frames
# dusje.mp4: 57 frames
# e-coli.mp4: 61 frames
# ebola.mp4: 29 frames
# eeg.mp4: 59 frames
# eggcelle.mp4: 54 frames
# egoisme.mp4: 57 frames
# ekg.mp4: 45 frames
# eksem-2.mp4: 61 frames
# eksem-5.mp4: 53 frames
# eksem.mp4: 61 frames
# eksponering.mp4: 56 frames
# elske-1.mp4: 46 frames
# elske-2.mp4: 45 frames
# elske-sex.mp4: 48 frames
# emosjonelt-ustabil-personlighetsforstyrrelse.mp4: 112 frames
# endetarm-2.mp4: 58 frames
# energi.mp4: 48 frames
# engstelig.mp4: 63 frames
# epidemi.mp4: 55 frames
# epilepsi-2.mp4: 66 frames
# epilepsi-3.mp4: 56 frames
# epilepsi.mp4: 71 frames
# ereksjon.mp4: 49 frames
# erotisk-erotikk-1.mp4: 47 frames
# erotisk-erotikk-2.mp4: 42 frames
# evne.mp4: 37 frames
# fall-i-haaret.mp4: 10 frames
# falsk-krupp.mp4: 79 frames
# fasong.mp4: 58 frames
# faste-aa-faste.mp4: 54 frames
# fastlege.mp4: 65 frames
# fatle.mp4: 36 frames
# feber-1.mp4: 49 frames
# feber-2.mp4: 58 frames
# feberkurve.mp4: 65 frames
# fedme.mp4: 55 frames
# feminin.mp4: 50 frames
# fet-tykk.mp4: 52 frames
# fett.mp4: 40 frames
# figur.mp4: 52 frames
# fike-oerefik-1.mp4: 37 frames
# fike-oerefik-2.mp4: 51 frames
# fjes.mp4: 46 frames
# fluor.mp4: 40 frames
# foedselspsykose.mp4: 66 frames
# foedt.mp4: 43 frames
# foelelse.mp4: 41 frames
# foerstegradsforbrenning.mp4: 76 frames
# foflekk-1.mp4: 53 frames
# folketrygd.mp4: 51 frames
# forbinding-bandasje.mp4: 55 frames
# fordoeye-lse.mp4: 56 frames
# fordoyelsessystem.mp4: 90 frames
# forebygge.mp4: 46 frames
# forelsket.mp4: 38 frames
# forfengelig-het.mp4: 56 frames
# forfrosning.mp4: 56 frames
# forgifte.mp4: 40 frames
# forkjoelet-forkjoelelse.mp4: 47 frames
# forkjoelet.mp4: 47 frames
# formering.mp4: 52 frames
# forplante.mp4: 51 frames
# forske.mp4: 45 frames
# forstand.mp4: 51 frames
# forstehjelp.mp4: 69 frames
# forstehjelpskurs.mp4: 68 frames
# forstoeverapparat-2.mp4: 86 frames
# fortann.mp4: 44 frames
# foster-2.mp4: 62 frames
# foster-3.mp4: 55 frames
# foster-4.mp4: 55 frames
# foster.mp4: 52 frames
# fot-1.mp4: 44 frames
# fregner.mp4: 43 frames
# frisk-fysisk.mp4: 45 frames
# frysninger.mp4: 61 frames
# full-beruset.mp4: 55 frames
# funksjonshemmet.mp4: 55 frames
# fysiologi.mp4: 47 frames
# fysioterapeut.mp4: 67 frames
# fysioterapi.mp4: 59 frames
# fysisk.mp4: 55 frames
# galleblaere-1.mp4: 62 frames
# gebiss-1.mp4: 51 frames
# gebiss-2.mp4: 43 frames
# generalisert-angstlidelse.mp4: 90 frames
# gift-ig.mp4: 42 frames
# gips-bandasje-2.mp4: 46 frames
# graate-2.mp4: 52 frames
# grader-temperatur.mp4: 53 frames
# gravid-itet.mp4: 37 frames
# gynekolog.mp4: 44 frames
# haar-tykt-og-kroellet.mp4: 37 frames
# haar-tykt-og-smaakroellet.mp4: 55 frames
# haar.mp4: 31 frames
# haarklipp.mp4: 50 frames
# haarvask.mp4: 53 frames
# hael-paa-foten.mp4: 56 frames
# hallusinasjon.mp4: 56 frames
# hals-lang-hals.mp4: 44 frames
# hals.mp4: 46 frames
# halte.mp4: 59 frames
# halvlangt-haar.mp4: 48 frames
# handikap.mp4: 48 frames
# helse-1.mp4: 51 frames
# helse-2.mp4: 45 frames
# helsepersonell-loven.mp4: 75 frames
# hemmet.mp4: 42 frames
# hemorider-2.mp4: 57 frames
# hemorider.mp4: 56 frames
# henvise-1.mp4: 48 frames
# henvise-2.mp4: 43 frames
# hes.mp4: 54 frames
# heterofili.mp4: 54 frames
# hevelse.mp4: 58 frames
# hinke.mp4: 53 frames
# hjelpepleier.mp4: 54 frames
# hjerne.mp4: 48 frames
# hjernehinnebetennelse.mp4: 88 frames
# hjernekreft.mp4: 66 frames
# hjernerystelse-1.mp4: 84 frames
# hjernerystelse-2.mp4: 83 frames
# hjerneslag.mp4: 70 frames
# hjerte-2.mp4: 54 frames
# hjerte-kars-sykdom.mp4: 85 frames
# hjerteinfarkt.mp4: 52 frames
# hjertekammer-1.mp4: 65 frames
# hjertekammer-2.mp4: 63 frames
# hjerteklaff.mp4: 63 frames
# hjertesvikt.mp4: 73 frames
# hodepine.mp4: 50 frames
# hoere-stemmer.mp4: 66 frames
# hoere.mp4: 32 frames
# hoereapparat.mp4: 43 frames
# hoersel.mp4: 34 frames
# hoerselshemmet.mp4: 51 frames
# hoerselsnerve-1.mp4: 56 frames
# hoerselsnerve-2.mp4: 59 frames
# hoerselssentral.mp4: 56 frames
# hoerselsvern.mp4: 63 frames
# homofili.mp4: 55 frames
# hoste.mp4: 49 frames
# hostesaft.mp4: 51 frames
# hoven-kinn.mp4: 46 frames
# hovne-lymfekjertler.mp4: 47 frames
# hud-1.mp4: 54 frames
# hud-2.mp4: 54 frames
# hud-3.mp4: 47 frames
# hud.mp4: 46 frames
# hudkreft.mp4: 53 frames
# hudvev.mp4: 62 frames
# hygiene-isk.mp4: 46 frames
# hysterioform-personlighetsforstyrrelse.mp4: 97 frames
# immunforsvar.mp4: 68 frames
# impotens.mp4: 41 frames
# impotent.mp4: 48 frames
# individuell-plan.mp4: 70 frames
# infarkt-hjerteinfarkt.mp4: 41 frames
# infeksjon-2.mp4: 53 frames
# infeksjon.mp4: 43 frames
# influensa.mp4: 57 frames
# inhalator.mp4: 52 frames
# innblaasning-hlr.mp4: 58 frames
# innlagt.mp4: 47 frames
# innvendig.mp4: 51 frames
# isolert.mp4: 49 frames
# jeksel.mp4: 53 frames
# jomfru.mp4: 46 frames
# jordmor.mp4: 54 frames
# kaste-opp-oppkast-1.mp4: 42 frames
# kaste-opp-oppkast-2.mp4: 50 frames
# keisersnitt.mp4: 50 frames
# keivhendt.mp4: 62 frames
# kikhoste.mp4: 67 frames
# kinn.mp4: 51 frames
# kirurgi.mp4: 57 frames
# kjaele-klemme.mp4: 55 frames
# kjaereste.mp4: 55 frames
# kjaerlighet.mp4: 55 frames
# kjenne-foele.mp4: 49 frames
# kjeve.mp4: 46 frames
# kjeveben.mp4: 51 frames
# kjoenn.mp4: 43 frames
# kjoennsmodning.mp4: 70 frames
# klimaks.mp4: 49 frames
# klinikk-1.mp4: 46 frames
# klinikk-2.mp4: 47 frames
# klippe-haaret.mp4: 53 frames
# klore-andre.mp4: 45 frames
# klore-meg.mp4: 50 frames
# kne.mp4: 48 frames
# kognitive-forstyrrelser.mp4: 80 frames
# kolesterol.mp4: 61 frames
# kompresjon-hjerte.mp4: 56 frames
# kondom.mp4: 45 frames
# kort-haar.mp4: 41 frames
# krampe.mp4: 52 frames
# krampeanfall.mp4: 69 frames
# kreft-3.mp4: 62 frames
# kreft.mp4: 52 frames
# krem-hudkrem.mp4: 52 frames
# kremasjon.mp4: 57 frames
# kremere.mp4: 57 frames
# kretslop-anatomi-2.mp4: 66 frames
# kretslop-anatomi.mp4: 54 frames
# kroeller.mp4: 49 frames
# kronisk-1.mp4: 56 frames
# kronisk-2.mp4: 60 frames
# kropp-paa-kroppen.mp4: 24 frames
# kropp.mp4: 44 frames
# kroppslige-reaksjoner.mp4: 69 frames
# krum-nese-oernenese.mp4: 58 frames
# kunstig.mp4: 52 frames
# kurve-feberkurve-ol.mp4: 50 frames
# kusma-2.mp4: 58 frames
# kusma-3.mp4: 57 frames
# kusma.mp4: 65 frames
# kvalm.mp4: 60 frames
# kvele.mp4: 46 frames
# kvise.mp4: 56 frames
# kyss.mp4: 45 frames
# kysse.mp4: 49 frames
# kyssesyke.mp4: 62 frames
# la-maten-synke.mp4: 53 frames
# laarhalsbrudd.mp4: 63 frames
# langt-haar.mp4: 54 frames
# ledd-del.mp4: 45 frames
# lege-doktor.mp4: 45 frames
# legeme.mp4: 47 frames
# legevakt.mp4: 53 frames
# legevisitt.mp4: 57 frames
# legg-paa-benet.mp4: 44 frames
# legge-paa.mp4: 51 frames
# legge-seg.mp4: 40 frames
# lei-t-trist.mp4: 40 frames
# leppe-1.mp4: 42 frames
# leppe-2.mp4: 54 frames
# lesbisk-1.mp4: 53 frames
# lesbisk-2.mp4: 48 frames
# lettere-depresjon.mp4: 64 frames
# leukemi-1.mp4: 59 frames
# lever-organ.mp4: 49 frames
# leverkreft.mp4: 70 frames
# lide-lse.mp4: 45 frames
# lidelse.mp4: 60 frames
# ligge-om-person-1.mp4: 33 frames
# ligge-om-person-2.mp4: 57 frames
# lik-doed-person.mp4: 52 frames
# liv-1.mp4: 50 frames
# liv-2.mp4: 33 frames
# livsforsikring.mp4: 56 frames
# livsglede.mp4: 62 frames
# loes-mage.mp4: 56 frames
# luft.mp4: 44 frames
# luftror-1.mp4: 62 frames
# luftvei.mp4: 50 frames
# luftveisinfeksjon.mp4: 76 frames
# lukke-oeynene.mp4: 45 frames
# lukte-1.mp4: 55 frames
# lukte-2.mp4: 51 frames
# lunge-2.mp4: 56 frames
# lunge.mp4: 62 frames
# lungebetennelse.mp4: 75 frames
# lungekreft.mp4: 81 frames
# lungesykdom.mp4: 75 frames
# lyst.mp4: 45 frames
# maale-blodsukker.mp4: 53 frames
# maane-om-haar.mp4: 61 frames
# maanedlige.mp4: 54 frames
# magen.mp4: 49 frames
# mandler-kjertel-2.mp4: 54 frames
# mani.mp4: 45 frames
# manisk-depressiv-lidelse.mp4: 99 frames
# maskulin.mp4: 57 frames
# me-myalgisk-encefalopati.mp4: 47 frames
# medisin-2.mp4: 50 frames
# medisin-3.mp4: 51 frames
# medisin.mp4: 51 frames
# mellomgulv-anatomi.mp4: 54 frames
# meningsfylt-liv.mp4: 72 frames
# menisk-1.mp4: 49 frames
# menisk-2.mp4: 54 frames
# menneske-1.mp4: 54 frames
# menneske-2.mp4: 52 frames
# menstruasjon-mens-1.mp4: 51 frames
# menstruasjon-mens-2.mp4: 43 frames
# mental.mp4: 50 frames
# meslinger-2.mp4: 60 frames
# meslinger.mp4: 72 frames
# mestring.mp4: 48 frames
# migrene.mp4: 51 frames
# milt.mp4: 48 frames
# moden-modent.mp4: 51 frames
# mosjon.mp4: 50 frames
# mosjonere.mp4: 46 frames
# ms-multippel-sklerose.mp4: 49 frames
# muskel.mp4: 50 frames
# muskelvev.mp4: 67 frames
# naersynt.mp4: 35 frames
# naken-1.mp4: 50 frames
# naken-2.mp4: 51 frames
# nakke.mp4: 49 frames
# narkomani.mp4: 56 frames
# narkose-1.mp4: 54 frames
# narkose-2.mp4: 55 frames
# narkotika.mp4: 56 frames
# navle.mp4: 43 frames
# nedfor-deprimert.mp4: 49 frames
# negative-symptomer.mp4: 72 frames
# negl.mp4: 46 frames
# nerve-1.mp4: 54 frames
# nerve-2.mp4: 50 frames
# nerve-4.mp4: 41 frames
# nerve-5.mp4: 43 frames
# nervoes-1.mp4: 44 frames
# nervoes-2.mp4: 47 frames
# nese-oppstoppernese.mp4: 44 frames
# nese-spiss.mp4: 35 frames
# nese-stor-klumpet.mp4: 38 frames
# nese.mp4: 38 frames
# nesehulen.mp4: 60 frames
# normal.mp4: 52 frames
# nyse.mp4: 51 frames
# observasjon.mp4: 47 frames
# oem-2.mp4: 41 frames
# oem-oemt-saar.mp4: 45 frames
# oere-1.mp4: 54 frames
# oere-2.mp4: 45 frames
# oere-3.mp4: 46 frames
# oere-lite-oere.mp4: 53 frames
# oere-stort-oere.mp4: 55 frames
# oerebetennelse.mp4: 73 frames
# oerepropp.mp4: 54 frames
# oerespesialist.mp4: 67 frames
# oeresus.mp4: 56 frames
# oeretelefon.mp4: 61 frames
# oereverk.mp4: 76 frames
# oerevoks.mp4: 61 frames
# oeyeblikkelig-hjelp.mp4: 66 frames
# oeyne-2.mp4: 53 frames
# oeyne.mp4: 65 frames
# operasjon.mp4: 49 frames
# oppkast.mp4: 44 frames
# opptrening.mp4: 52 frames
# organ.mp4: 53 frames
# orgasme.mp4: 56 frames
# overkryssing.mp4: 68 frames
# p-pille.mp4: 60 frames
# paakjenning.mp4: 50 frames
# paaroerende.mp4: 51 frames
# panikklidelse.mp4: 71 frames
# panne.mp4: 54 frames
# paracet.mp4: 69 frames
# paranoia-1.mp4: 56 frames
# paranoid.mp4: 54 frames
# pasient.mp4: 55 frames
# pasientrettighetsloven.mp4: 81 frames
# penis.mp4: 52 frames
# personlighetsforstyrrelse.mp4: 64 frames
# pervers-perversitet.mp4: 47 frames
# pest.mp4: 45 frames
# pirquet-prove.mp4: 63 frames
# plaster.mp4: 47 frames
# pleier-sykepleier.mp4: 51 frames
# plombere-tann.mp4: 58 frames
# poliklinikk.mp4: 74 frames
# polio.mp4: 58 frames
# polypp.mp4: 45 frames
# pornografi-sk.mp4: 65 frames
# positive-symptomer.mp4: 73 frames
# posttraumatisk-stressforstyrrelse.mp4: 117 frames
# prevensjon-preventiv.mp4: 57 frames
# privatpraktiserende.mp4: 77 frames
# prolaps-1.mp4: 50 frames
# prolaps-2.mp4: 51 frames
# promille.mp4: 53 frames
# propp-oerepropp.mp4: 44 frames
# prostituert.mp4: 53 frames
# prostitusjon.mp4: 60 frames
# psyke-2.mp4: 47 frames
# psykiater-2.mp4: 68 frames
# psykiater.mp4: 44 frames
# psykiatri-sk.mp4: 48 frames
# psykiatrisk-poliklinikk.mp4: 90 frames
# psykisk-2.mp4: 63 frames
# psykisk-helse.mp4: 60 frames
# psykisk-lidelse.mp4: 74 frames
# psykisk.mp4: 50 frames
# psykiske-problemer.mp4: 67 frames
# psykoanalyse.mp4: 72 frames
# psykolog.mp4: 50 frames
# psykologi-sk.mp4: 49 frames
# psykose.mp4: 49 frames
# psykososial-1.mp4: 68 frames
# psykososial-2.mp4: 68 frames
# psykotisk-episode.mp4: 69 frames
# pubertet.mp4: 53 frames
# pudder-pudre.mp4: 52 frames
# pudder-talkum.mp4: 44 frames
# puls.mp4: 47 frames
# pungen-scrotum.mp4: 55 frames
# pusse-tenner-1.mp4: 43 frames
# pusse-tenner-2.mp4: 47 frames
# puste.mp4: 48 frames
# pusteproblemer.mp4: 79 frames
# reaksjon.mp4: 45 frames
# redd-bite-seg-i-fingrene.mp4: 53 frames
# redd-haaret-reiser-seg-paa-hodet.mp4: 47 frames
# redsel.mp4: 56 frames
# regelmessig.mp4: 54 frames
# resept.mp4: 43 frames
# rifle.mp4: 51 frames
# rift.mp4: 38 frames
# rode-hunder-sykdom-1.mp4: 72 frames
# roede-hunder.mp4: 71 frames
# roentgen-1.mp4: 42 frames
# roentgen-2.mp4: 42 frames
# roest-stemme.mp4: 45 frames
# roeyke.mp4: 47 frames
# rumle-i-magen-1.mp4: 53 frames
# runde-oeyne.mp4: 30 frames
# ryggrad-1.mp4: 57 frames
# ryggrad-2.mp4: 57 frames
# rynker.mp4: 65 frames
# saape.mp4: 49 frames
# saar.mp4: 42 frames
# saarbarhet.mp4: 51 frames
# saed.mp4: 33 frames
# salve.mp4: 56 frames
# samleie.mp4: 45 frames
# samliv.mp4: 53 frames
# samtaleterapi.mp4: 73 frames
# sans.mp4: 35 frames
# schizoaffektiv-psykose.mp4: 97 frames
# schizofren-1.mp4: 45 frames
# schizofren-2.mp4: 50 frames
# schizofreni-3.mp4: 62 frames
# schizofreni.mp4: 60 frames
# schizoid-personlighetsforstyrrelse.mp4: 84 frames
# seksualitet.mp4: 52 frames
# seksuell.mp4: 48 frames
# seksuelle-overgrep.mp4: 79 frames
# selvfoelelse.mp4: 64 frames
# selvhjelp.mp4: 56 frames
# selvmord.mp4: 46 frames
# selvmordstanker.mp4: 75 frames
# selvskading.mp4: 60 frames
# sette-insulin.mp4: 52 frames
# sex.mp4: 32 frames
# signalstoffer-i-hjernen.mp4: 82 frames
# sine.mp4: 37 frames
# sinn.mp4: 41 frames
# sinnssyk.mp4: 53 frames
# sjel.mp4: 37 frames
# sjokk.mp4: 37 frames
# skade.mp4: 43 frames
# skallet-haarloest-hode-1.mp4: 46 frames
# skallet-haarloest-hode-2.mp4: 48 frames
# skill-i-haaret.mp4: 54 frames
# skinke.mp4: 62 frames
# skinn-hud.mp4: 36 frames
# skjele.mp4: 49 frames
# skjelett.mp4: 52 frames
# skjeloeyd.mp4: 53 frames
# skyldfoelelse.mp4: 65 frames
# skylle-oeret.mp4: 54 frames
# skyllevaeske.mp4: 56 frames
# slank.mp4: 44 frames
# slapp.mp4: 44 frames
# sluke-svelge-1.mp4: 46 frames
# sluke-svelge-2.mp4: 42 frames
# smake-smake-paa-flere.mp4: 52 frames
# smake.mp4: 38 frames
# smale-oeyne.mp4: 45 frames
# smerte-lig-1.mp4: 53 frames
# smerte-lig-2.mp4: 55 frames
# smitte.mp4: 41 frames
# smoere-med-salve.mp4: 42 frames
# soester-sykesoester.mp4: 46 frames
# soevn-2.mp4: 51 frames
# sosial-angst.mp4: 59 frames
# sosial-kontakt.mp4: 66 frames
# sosial-situasjon.mp4: 70 frames
# sosionom.mp4: 51 frames
# spesialist.mp4: 40 frames
# spiral-prevensjon.mp4: 46 frames
# sproeyte-1.mp4: 44 frames
# sproeyte-2.mp4: 55 frames
# stabilt-sideleie.mp4: 70 frames
# stemme.mp4: 50 frames
# sterilisere-ing.mp4: 50 frames
# store-runde-oeyne.mp4: 37 frames
# stortaa.mp4: 51 frames
# straalebehandling.mp4: 62 frames
# strupe.mp4: 50 frames
# stum.mp4: 39 frames
# svaer-muskuloes.mp4: 23 frames
# svanger-skap.mp4: 50 frames
# svett.mp4: 37 frames
# svimmel.mp4: 62 frames
# syk-2.mp4: 64 frames
# syk.mp4: 32 frames
# sykdom.mp4: 61 frames
# sykehjem.mp4: 58 frames
# sykehusinnleggelse.mp4: 82 frames
# sykepleie-r.mp4: 41 frames
# sykepleier.mp4: 54 frames
# sykesoester.mp4: 51 frames
# sykmeldt.mp4: 56 frames
# syn.mp4: 44 frames
# syre.mp4: 43 frames
# taare.mp4: 50 frames
# tablett.mp4: 37 frames
# tampong.mp4: 47 frames
# tankeforstyrrelser.mp4: 72 frames
# tann.mp4: 41 frames
# tannbyll.mp4: 59 frames
# tannpine.mp4: 67 frames
# tannpirker.mp4: 49 frames
# tannregulering.mp4: 54 frames
# temperament.mp4: 59 frames
# temperatur.mp4: 55 frames
# terapeut.mp4: 48 frames
# terapi-terapeutisk.mp4: 45 frames
# termin.mp4: 50 frames
# tilfoeye-lse.mp4: 45 frames
# tisse.mp4: 44 frames
# toalett.mp4: 39 frames
# traume.mp4: 63 frames
# tredjegradsforbrenning-1.mp4: 83 frames
# tredjegradsforbrenning-2.mp4: 84 frames
# trekke-trekke-en-tann.mp4: 43 frames
# trygghet.mp4: 41 frames
# tunge.mp4: 43 frames
# tunghoert.mp4: 42 frames
# tvangsmessig-personlighetsforstyrrelse.mp4: 85 frames
# tykk-nese.mp4: 55 frames
# tykk.mp4: 48 frames
# tynn-mager.mp4: 36 frames
# tynn.mp4: 34 frames
# ubehagelig.mp4: 45 frames
# undersoeke-lse.mp4: 52 frames
# unnvikende-personlighetsforstyrrelse.mp4: 85 frames
# urin.mp4: 41 frames
# urinblaeren.mp4: 59 frames
# utflod.mp4: 69 frames
# utvendig.mp4: 43 frames
# uvel-kvalm.mp4: 62 frames
# vaeske.mp4: 33 frames
# vaksinasjon.mp4: 47 frames
# vaske-ansiktet.mp4: 54 frames
# vaske-hendene.mp4: 43 frames
# vaske-opp.mp4: 43 frames
# veer.mp4: 48 frames
# verre.mp4: 33 frames
# vinterdepresjon.mp4: 70 frames
# visdomstann.mp4: 55 frames
# vold-2.mp4: 40 frames
# voldta.mp4: 46 frames
# voldtekt.mp4: 36 frames
# vondt-1.mp4: 52 frames
# vondt-2.mp4: 58 frames
# vrangforestillinger.mp4: 70 frames
# vrikke-over-1.mp4: 55 frames
# vrikke-over-2.mp4: 51 frames

# %%
# Frame count ranges for the video_folder (original videos)

frame_count_ranges = {
    '0-9': 0,
    '10-19': 0,
    '20-29': 0,
    '30-39': 0,
    '40-49': 0,
    '50-59': 0,
    '60-69': 0,
    '70-79': 0,
    '80-89': 0,
    '90-99': 0,
    '100-119': 0
}

def get_frame_count(video_path):
    cap = cv2.VideoCapture(video_path)
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    cap.release()
    return frame_count

for video_name in os.listdir(video_folder):
    video_path = os.path.join(video_folder, video_name)
    
    if os.path.isfile(video_path) and video_path.lower().endswith(('.mp4')):  
        frame_count = get_frame_count(video_path)

        if 0 <= frame_count <= 9:
            frame_count_ranges['0-9'] += 1
        elif 10 <= frame_count <= 19:
            frame_count_ranges['10-19'] += 1
        elif 20 <= frame_count <= 29:
            frame_count_ranges['20-29'] += 1
        elif 30 <= frame_count <= 39:
            frame_count_ranges['30-39'] += 1
        elif 40 <= frame_count <= 49:
            frame_count_ranges['40-49'] += 1
        elif 50 <= frame_count <= 59:
            frame_count_ranges['50-59'] += 1
        elif 60 <= frame_count <= 69:
            frame_count_ranges['60-69'] += 1
        elif 70 <= frame_count <= 79:
            frame_count_ranges['70-79'] += 1
        elif 80 <= frame_count <= 89:
            frame_count_ranges['80-89'] += 1
        elif 90 <= frame_count <= 99:
            frame_count_ranges['90-99'] += 1
        else:
            frame_count_ranges['100-119'] += 1

for frame_range, count in frame_count_ranges.items():
    print(f'Number of videos with {frame_range} frames: {count}')
# Out:
# Number of videos with 0-9 frames: 0
# Number of videos with 10-19 frames: 1
# Number of videos with 20-29 frames: 3
# Number of videos with 30-39 frames: 43
# Number of videos with 40-49 frames: 207
# Number of videos with 50-59 frames: 271
# Number of videos with 60-69 frames: 117
# Number of videos with 70-79 frames: 45
# Number of videos with 80-89 frames: 22
# Number of videos with 90-99 frames: 6
# Number of videos with 100-119 frames: 3

# %%
# df after preparations 

df = pd.read_excel(metadata)
df.head()
# Out:
#              Health_Term                    Video_File
# 0    1. gradsforbrenning   foerstegradsforbrenning.mp4
# 1    2. gradsforbrenning     andregradsforbrenning.mp4
# 2  3. gradsforbrenning 1  tredjegradsforbrenning-1.mp4
# 3  3. gradsforbrenning 2  tredjegradsforbrenning-2.mp4
# 4                  abort                     abort.mp4

# %%
video_folder = "helse_tegn"

min_frames = float('inf')
max_frames = 0

for filename in os.listdir(video_folder):
    if filename.endswith(".mp4"): 
        video_path = os.path.join(video_folder, filename)
        cap = cv2.VideoCapture(video_path)
        if not cap.isOpened():
            print(f"Failed to open video: {filename}")
            continue

        frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        min_frames = min(min_frames, frame_count)
        max_frames = max(max_frames, frame_count)
        cap.release()

print(f"Minimum number of frames: {min_frames}")
print(f"Maximum number of frames: {max_frames}")
# Out:
# Minimum number of frames: 10
# Maximum number of frames: 117

# %%
# Augmented folder

frame_count_ranges = {
    '0-9': 0,
    '10-19': 0,
    '20-29': 0,
    '30-39': 0,
    '40-49': 0,
    '50-59': 0,
    '60-69': 0,
    '70-79': 0,
    '80-89': 0,
    '90-99': 0,
    '100-119': 0
}

video_counter = 0

def get_frame_count(video_path):
    cap = cv2.VideoCapture(video_path)
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    cap.release()
    return frame_count

for term_folder in os.listdir(aug_folder):
    term_path = os.path.join(aug_folder, term_folder)

    if os.path.isdir(term_path):
        for video_name in os.listdir(term_path):
            video_path = os.path.join(term_path, video_name)

            if os.path.isfile(video_path) and video_path.lower().endswith('.mp4'):
                frame_count = get_frame_count(video_path)
                video_counter += 1

                if 0 <= frame_count <= 9:
                    frame_count_ranges['0-9'] += 1
                elif 10 <= frame_count <= 19:
                      frame_count_ranges['10-19'] += 1
                elif 20 <= frame_count <= 29:
                     frame_count_ranges['20-29'] += 1
                elif 30 <= frame_count <= 39:
                      frame_count_ranges['30-39'] += 1
                elif 40 <= frame_count <= 49:
                      frame_count_ranges['40-49'] += 1
                elif 50 <= frame_count <= 59:
                    frame_count_ranges['50-59'] += 1
                elif 60 <= frame_count <= 69:
                     frame_count_ranges['60-69'] += 1
                elif 70 <= frame_count <= 79:
                     frame_count_ranges['70-79'] += 1
                elif 80 <= frame_count <= 89:
                     frame_count_ranges['80-89'] += 1
                elif 90 <= frame_count <= 99:
                     frame_count_ranges['90-99'] += 1
                else:
                    frame_count_ranges['100-119'] += 1

print(f"\nTotal videos counted: {video_counter}\n")
for frame_range, count in frame_count_ranges.items():
    print(f'Number of videos with {frame_range} frames: {count}')
# Out:
# Total videos counted: 5840
#
# Number of videos with 0-9 frames: 0
# Number of videos with 10-19 frames: 16
# Number of videos with 20-29 frames: 36
# Number of videos with 30-39 frames: 444
# Number of videos with 40-49 frames: 1698
# Number of videos with 50-59 frames: 2161
# Number of videos with 60-69 frames: 896
# Number of videos with 70-79 frames: 352
# Number of videos with 80-89 frames: 171
# Number of videos with 90-99 frames: 38
# Number of videos with 100-119 frames: 28

# %%
# zero_pad_resized_224 folder

frame_count_ranges = {
    '0-9': 0,
    '10-19': 0,
    '20-29': 0,
    '30-39': 0,
    '40-49': 0,
    '50-59': 0,
    '60-69': 0,
    '70-79': 0,
    '80-89': 0,
    '90-99': 0,
    '100-119': 0
}

video_counter = 0

def get_frame_count(video_path):
    cap = cv2.VideoCapture(video_path)
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    cap.release()
    return frame_count

for term_folder in os.listdir(aug_resized_224):
    term_path = os.path.join(aug_resized_224, term_folder)

    if os.path.isdir(term_path):
        for video_name in os.listdir(term_path):
            video_path = os.path.join(term_path, video_name)

            if os.path.isfile(video_path) and video_path.lower().endswith('.mp4'):
                frame_count = get_frame_count(video_path)
                video_counter += 1

                if 0 <= frame_count <= 9:
                    frame_count_ranges['0-9'] += 1
                elif 10 <= frame_count <= 19:
                      frame_count_ranges['10-19'] += 1
                elif 20 <= frame_count <= 29:
                     frame_count_ranges['20-29'] += 1
                elif 30 <= frame_count <= 39:
                      frame_count_ranges['30-39'] += 1
                elif 40 <= frame_count <= 49:
                      frame_count_ranges['40-49'] += 1
                elif 50 <= frame_count <= 59:
                    frame_count_ranges['50-59'] += 1
                elif 60 <= frame_count <= 69:
                     frame_count_ranges['60-69'] += 1
                elif 70 <= frame_count <= 79:
                     frame_count_ranges['70-79'] += 1
                elif 80 <= frame_count <= 89:
                     frame_count_ranges['80-89'] += 1
                elif 90 <= frame_count <= 99:
                     frame_count_ranges['90-99'] += 1
                else:
                    frame_count_ranges['100-119'] += 1

print(f"\nTotal videos counted: {video_counter}\n")
for frame_range, count in frame_count_ranges.items():
    print(f'Number of videos with {frame_range} frames: {count}')
# Out:
# Total videos counted: 5840
#
# Number of videos with 0-9 frames: 0
# Number of videos with 10-19 frames: 0
# Number of videos with 20-29 frames: 0
# Number of videos with 30-39 frames: 0
# Number of videos with 40-49 frames: 0
# Number of videos with 50-59 frames: 0
# Number of videos with 60-69 frames: 0
# Number of videos with 70-79 frames: 0
# Number of videos with 80-89 frames: 0
# Number of videos with 90-99 frames: 0
# Number of videos with 100-119 frames: 5840

# %%
def check_fps_in_folder(folder_path):
    fps_values = set()  

    # Iterate over each term folder in the augmented folder
    for term_name in os.listdir(folder_path):
        term_path = os.path.join(folder_path, term_name)
        if os.path.isdir(term_path):
            for video_file in os.listdir(term_path):
                if video_file.endswith('.mp4'):
                    video_path = os.path.join(term_path, video_file)
                    
                    cap = cv2.VideoCapture(video_path)
                    if not cap.isOpened():
                        print(f"ERROR: Could not open video {video_path}")
                        continue
                    
                    fps = cap.get(cv2.CAP_PROP_FPS)
                    fps_values.add(fps)  
                    
                    cap.release()
                    print(f"Video: {video_file}, FPS: {fps}")
    
    if len(fps_values) == 1:
        print("All videos have the same FPS.")
    else:
        print(f"Different FPS values found: {fps_values}")

aug_folder = "aug_videos"
check_fps_in_folder(aug_folder)
# Out:
# Video: aug_1_foerstegradsforbrenning.mp4, FPS: 25.0
# Video: aug_2_foerstegradsforbrenning.mp4, FPS: 25.0
# Video: aug_3_foerstegradsforbrenning.mp4, FPS: 25.0
# Video: aug_4_foerstegradsforbrenning.mp4, FPS: 25.0
# Video: aug_5_foerstegradsforbrenning.mp4, FPS: 25.0
# Video: aug_6_foerstegradsforbrenning.mp4, FPS: 25.0
# Video: aug_7_foerstegradsforbrenning.mp4, FPS: 25.0
# Video: aug_8_foerstegradsforbrenning.mp4, FPS: 25.0
# Video: aug_9_foerstegradsforbrenning.mp4, FPS: 25.0
# Video: foerstegradsforbrenning.mp4, FPS: 25.0
# Video: andregradsforbrenning.mp4, FPS: 25.0
# Video: aug_1_andregradsforbrenning.mp4, FPS: 25.0
# Video: aug_2_andregradsforbrenning.mp4, FPS: 25.0
# Video: aug_3_andregradsforbrenning.mp4, FPS: 25.0
# Video: aug_4_andregradsforbrenning.mp4, FPS: 25.0
# Video: aug_5_andregradsforbrenning.mp4, FPS: 25.0
# Video: aug_6_andregradsforbrenning.mp4, FPS: 25.0
# Video: aug_7_andregradsforbrenning.mp4, FPS: 25.0
# Video: aug_8_andregradsforbrenning.mp4, FPS: 25.0
# Video: aug_9_andregradsforbrenning.mp4, FPS: 25.0
# Video: aug_1_tredjegradsforbrenning-1.mp4, FPS: 25.0
# Video: aug_2_tredjegradsforbrenning-1.mp4, FPS: 25.0
# Video: aug_3_tredjegradsforbrenning-1.mp4, FPS: 25.0
# Video: aug_4_tredjegradsforbrenning-1.mp4, FPS: 25.0
# Video: aug_5_tredjegradsforbrenning-1.mp4, FPS: 25.0
# Video: aug_6_tredjegradsforbrenning-1.mp4, FPS: 25.0
# Video: aug_7_tredjegradsforbrenning-1.mp4, FPS: 25.0
# Video: aug_8_tredjegradsforbrenning-1.mp4, FPS: 25.0
# Video: aug_9_tredjegradsforbrenning-1.mp4, FPS: 25.0
# Video: tredjegradsforbrenning-1.mp4, FPS: 25.0
